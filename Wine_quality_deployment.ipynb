# %%
import pandas as pd

# %%
wine_df= pd.read_csv('winequality-red.csv')
wine_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
wine_df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
wine_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
wine_df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
wine_df.shape
# Out:
# (1599, 12)

# %% [markdown]
# # Exploratory Analysis and Visualization

# %%
#  Let's begin by importingmatplotlib.pyplot and seaborn.

import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.set_style('darkgrid')
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (9, 5)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %%
wine_df.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
wine_df.sort_values('quality',ascending= False).head(10)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 495            10.7              0.35         0.53             2.6      0.070
# 1403            7.2              0.33         0.33             1.7      0.061
# 390             5.6              0.85         0.05             1.4      0.045
# 1061            9.1              0.40         0.50             1.8      0.071
# 1202            8.6              0.42         0.39             1.8      0.068
# 828             7.8              0.57         0.09             2.3      0.065
# 481             9.4              0.30         0.56             2.8      0.080
# 455            11.3              0.62         0.67             5.2      0.086
# 1449            7.2              0.38         0.31             2.0      0.056
# 440            12.6              0.31         0.72             2.2      0.072
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
wine_df[wine_df['quality']==8].count()
# Out:
# fixed acidity           18
# volatile acidity        18
# citric acid             18
# residual sugar          18
# chlorides               18
# free sulfur dioxide     18
# total sulfur dioxide    18
# density                 18
# pH                      18
# sulphates               18
# alcohol                 18
# quality                 18
# dtype: int64

# %%
#  Performing the feature Analysis:
# %matplotlib inline
wine_df.hist(bins=50, figsize=(20,15))
plt.show()

# %%
import numpy as np
plt.hist(wine_df.quality, bins=np.arange(3,9,1))
plt.xlabel('Wine Quality')
plt.ylabel('Quantity')
# Out:
# Text(0, 0.5, 'Quantity')

# %%
fig, axes = plt.subplots(1,2, figsize =(14,7))
axes[0].plot(wine_df.quality,wine_df.alcohol)
axes[1].set_title('Alcohol vs Quality')
sns.scatterplot(wine_df.quality,wine_df.alcohol)
# Out:
# /Users/pradeepvallepalli/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:title={'center':'Alcohol vs Quality'}, xlabel='quality', ylabel='alcohol'>

# %% [markdown]
# From the first plot, no clear relation between wine quality and amount of alcohol in it. From the second plot, an inference can be made that as the quality of wine increases, the alcohol resches to the greater amount or in other words, with the increase in maximum limit of alcohol,the quality increases but no relation is found between alcohol and quality.

# %% [markdown]
# Now, checking the effect of input parameters to the output variables, alcohol and quality.

# %%
# Pair Plot:
sns.pairplot(wine_df);

# %%
plt.figure(figsize = [15,10])
sns.heatmap(wine_df.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# This is correlation plot of all variables.

# %%
quality = wine_df['quality']
alcohol = wine_df['alcohol']

scatterplot_alcohol_density_quality = sns.scatterplot(
                y=wine_df['density'], 
                x=alcohol, s=150, hue=quality, palette='magma')

# %% [markdown]
# This is a scatterplot for alcohol and density, with quality as hue.

# %%
wine_df.alcohol.hist();

# %%
wine_df['alcohol_Category'] = pd.cut(wine_df["alcohol"],
                               bins=[0, 8, 9, 10, 11, 12, 13, 14, np.inf],
                               labels=[1, 2, 3, 4, 5, 6, 7, 8])

# %%
wine_df.alcohol_Category.hist();

# %%
wine_df.alcohol.hist();

# %%
sns.countplot(wine_df['pH'])
plt.show()
# Out:
# /Users/pradeepvallepalli/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(wine_df['alcohol'])
plt.show()
# Out:
# /Users/pradeepvallepalli/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(wine_df['fixed acidity'])
plt.show()
# Out:
# /Users/pradeepvallepalli/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(wine_df['volatile acidity'])
plt.show()
# Out:
# /Users/pradeepvallepalli/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(wine_df['citric acid'])
plt.show()
# Out:
# /Users/pradeepvallepalli/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # KDE plot:

# %%
sns.kdeplot(wine_df.query('quality > 2').quality)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='Density'>

# %% [markdown]
# # Distplot:

# %%
sns.distplot(wine_df['alcohol'])
# Out:
# /Users/pradeepvallepalli/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='alcohol', ylabel='Density'>

# %%
wine_df.plot(kind ='box',subplots = True, layout =(4,4),sharex = False)
# Out:
# fixed acidity               AxesSubplot(0.125,0.71587;0.168478x0.16413)
# volatile acidity         AxesSubplot(0.327174,0.71587;0.168478x0.16413)
# citric acid              AxesSubplot(0.529348,0.71587;0.168478x0.16413)
# residual sugar           AxesSubplot(0.731522,0.71587;0.168478x0.16413)
# chlorides                  AxesSubplot(0.125,0.518913;0.168478x0.16413)
# free sulfur dioxide     AxesSubplot(0.327174,0.518913;0.168478x0.16413)
# total sulfur dioxide    AxesSubplot(0.529348,0.518913;0.168478x0.16413)
# density                 AxesSubplot(0.731522,0.518913;0.168478x0.16413)
# pH                         AxesSubplot(0.125,0.321957;0.168478x0.16413)
# sulphates               AxesSubplot(0.327174,0.321957;0.168478x0.16413)
# alcohol                 AxesSubplot(0.529348,0.321957;0.168478x0.16413)
# quality                 AxesSubplot(0.731522,0.321957;0.168478x0.16413)
# dtype: object

# %%
wine_df.plot(kind ='density',subplots = True, layout =(4,4),sharex = False)
# Out:
# array([[<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>]],
#       dtype=object)

# %%
# Voilin Data:
sns.violinplot(x='quality', y='alcohol', data=wine_df)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='alcohol'>

# %% [markdown]
# # Feature Selection:

# %%
# Create Classification version of target variable:
wine_df['goodquality'] = [1 if x >= 7 else 0 for x in wine_df['quality']]# Separate feature variables and target variable
X = wine_df.drop(['quality','goodquality'], axis = 1)
Y = wine_df['goodquality']

# %%
# See proportion of good vs bad wines
wine_df['goodquality'].value_counts()
# Out:
# 0    1382
# 1     217
# Name: goodquality, dtype: int64

# %%
X
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
print(Y)
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1594    0
# 1595    0
# 1596    0
# 1597    0
# 1598    0
# Name: goodquality, Length: 1599, dtype: int64

# %% [markdown]
# # Feature Importance:

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

from sklearn.ensemble import ExtraTreesClassifier
classifiern = ExtraTreesClassifier()
classifiern.fit(X,Y)
score = classifiern.feature_importances_
print(score)
# Out:
# [0.07720446 0.09141155 0.09022263 0.06778716 0.06598758 0.06592814
#  0.07711807 0.07150219 0.06644717 0.10245543 0.13449281 0.0894428 ]

# %% [markdown]
# # Splitting Dataset:

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.3,random_state=7)

# %% [markdown]
# # LogisticRegression:

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train,Y_train)
Y_pred = model.predict(X_test)

from sklearn.metrics import accuracy_score,confusion_matrix
print("Accuracy Score:",accuracy_score(Y_test,Y_pred))
# Out:
# Accuracy Score: 0.875
# /Users/pradeepvallepalli/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
confusion_mat = confusion_matrix(Y_test,Y_pred)
print(confusion_mat)
# Out:
# [[401  16]
#  [ 44  19]]

# %% [markdown]
# # Using KNN:

# %%
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier(n_neighbors=3)
model.fit(X_train,Y_train)
y_pred = model.predict(X_test)

from sklearn.metrics import accuracy_score
print("Accuracy Score:",accuracy_score(Y_test,y_pred))
# Out:
# Accuracy Score: 0.85625

# %% [markdown]
# # Using SVC:

# %%
from sklearn.svm import SVC
model = SVC()
model.fit(X_train,Y_train)
pred_y = model.predict(X_test)

from sklearn.metrics import accuracy_score
print("Accuracy Score:",accuracy_score(Y_test,pred_y))
# Out:
# Accuracy Score: 0.86875

# %% [markdown]
# # Using Decision Tree:

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier(criterion='entropy',random_state=7)
model.fit(X_train,Y_train)
y_pred = model.predict(X_test)

from sklearn.metrics import accuracy_score
print("Accuracy Score:",accuracy_score(Y_test,y_pred))
# Out:
# Accuracy Score: 0.8604166666666667

# %% [markdown]
# #  Using GaussianNB:

# %%
from sklearn.naive_bayes import GaussianNB
model3 = GaussianNB()
model3.fit(X_train,Y_train)
y_pred3 = model3.predict(X_test)

from sklearn.metrics import accuracy_score
print("Accuracy Score:",accuracy_score(Y_test,y_pred3))
# Out:
# Accuracy Score: 0.8

# %% [markdown]
# #  Using Random Forest:

# %%
from sklearn.ensemble import RandomForestClassifier
model2 = RandomForestClassifier(random_state=1)
model2.fit(X_train, Y_train)
y_pred2 = model2.predict(X_test)

from sklearn.metrics import accuracy_score
print("Accuracy Score:",accuracy_score(Y_test,y_pred2))
# Out:
# Accuracy Score: 0.9020833333333333

# %%
results = pd.DataFrame({
    'Model': ['Logistic Regression','KNN', 'SVC','Decision Tree' ,'GaussianNB','Random Forest'],
    'Score': [0.875,0.856,0.868,0.860,0.8,0.902]})

result_df = results.sort_values(by='Score', ascending=False)
result_df = result_df.set_index('Score')
result_df
# Out:
#                      Model
# Score
# 0.902        Random Forest
# 0.875  Logistic Regression
# 0.868                  SVC
# 0.860        Decision Tree
# 0.856                  KNN
# 0.800           GaussianNB
